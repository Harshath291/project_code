# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#to access excel file 

pd.read_excel(r"path of the excel file")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 3
#       1 #to access excel file
# ----> 3 pd.read_excel(r"path of the excel file")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
# ...

# %%
claim_data=pd.read_csv(r"C:\Users\osman\Downloads\contacts_to_import.csv")
claim_data
# Out:
#       FNAME      LNAME          CELL                     EMAIL SALUTATION  \
# 0      John      Dodge  555-888-8888        jdodge@example.com        Mr.
# 1     Sarah      Smith  555-999-8888        ssnith@example.com        Ms.
# 2    George     Dapper  555-999-0000       gdapper@example.com        Dr.
# 3      Jack      Dodge  555-888-8888       jdodge2@example.com        Mr.
# 4   Jessica      Jones  555-999-8888        jjones@example.com       Mrs.
# 5    Dragon     Davich  555-999-0000       dragonr@example.com        Dr.
# 6     Steve      Curio  555-555-5454       curious@example.com        Mr.
# 7     Laura      Black  555-555-3434         black@example.com        Ms.
# 8   Wilhelm      Blake  555-555-5543        wblake@example.com        Mr.
# 9    Winter      Drake  555-555-5554       dragon2@example.com        Mr.
# 10      Sal      Sands  555-555-5553  sandssquared@example.com        Mr.
# 11    Julia      Wilds  555-555-9988        jwilds@example.com        Ms.
# ...

# %%
df1=sns.load_dataset('taxis')

# %%
sns.barplot(x='color',y='total',data=df1,color='red',estimator='mean')
plt.show()

# %%
sns.barplot(x='color',y='total',data=df1,color='red',estimator='sum')
plt.show()
plt.tight_layout()

# %%
sns.barplot(x='color',y='total',data=df1,color='red',estimator='min')
plt.show()

# %%
sns.barplot(x='color',y='total',data=df1,color='red',estimator='max')
plt.show()

# %%
sns.barplot(x='color',y='total',data=df1,color='red',estimator='var')
plt.show()

# %%
sns.barplot(x='payment',y='total',data=df1,color='red',estimator='sum')
plt.show()
plt.tight_layout()

# %%
sns.histplot(x=df1['fare'],color='pink')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(x=df1['fare'],color='pink',hue=df1['payment'])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(x=df1['fare'],palette=['blue','red'],hue=df1['payment'])
plt.show()

# %%
sns.violinplot(x=df1['fare'],y=df1['payment'],palette=['green','y'])
plt.show()

# %%
sns.boxplot(x=df1['fare'],y=df1['payment'],palette=['b','r'])
# Out:
# <Axes: xlabel='fare', ylabel='payment'>

# %%
sns.scatterplot(x=df1['fare'],y=df1['total'],palette=['yellow','red'],hue=df1['payment'])
plt.show()

# %%
sns.stripplot(y=df1['color'],x=df1['fare'],palette=['yellow','red'],)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
iris_data=sns.load_dataset('iris')
df=sns.load_dataset('taxis')

# %%
sns.scatterplot(x=iris_data['sepal_length'],y=iris_data['petal_length'])
plt.show()

# %%
sns.scatterplot(x=iris_data['sepal_length'],y=iris_data['petal_length'],hue=iris_data['species'],palette=['r','g','y'])
plt.show()

# %%
sns.stripplot(x=df['payment'],y=df['tip'],palette=['r','g','y'])
plt.show()

# %%
sns.stripplot(x=df['payment'],y=df['total'],palette=['r','g','y'])
plt.show()

# %%
sns.lineplot(x=df['total'],y=df['fare'],)
plt.show()

# %%
sns.lineplot(x=df['total'],y=df['fare'],hue=df['payment'],palette=['red','orange'])
plt.show()

# %%
df[(df['payment']=='cash') & (df['tip']>0)]
# Out:
# Empty DataFrame
# Columns: [pickup, dropoff, passengers, distance, fare, tip, tolls, total, color, payment, pickup_zone, dropoff_zone, pickup_borough, dropoff_borough]
# Index: []

# %%
sns.lineplot(x=df['total'],y=df['fare'],hue=df['payment'],palette=['red','orange'])
plt.show()

# %%
sns.lineplot(x=df['total'],y=df['fare'],)
plt.show()

# %%
sns.stripplot(x=df['payment'],y=df['total'],palette=['r','g','y'])
plt.show()

# %%
sns.stripplot(x=df['payment'],y=df['tip'],palette=['r','g','y'])
plt.show()

# %%
df[['payment','color']].value_counts()
# Out:
# payment      color
# credit card  yellow    4000
# cash         yellow    1412
# credit card  green      577
# cash         green      400
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# yellow    5451
# green      982
# Name: count, dtype: int64

# %%
df['payment'].value_counts()
# Out:
# payment
# credit card    4577
# cash           1812
# Name: count, dtype: int64

# %%
sns.countplot(x=df['payment'])
# Out:
# <Axes: xlabel='payment', ylabel='count'>

# %%
sns.countplot(x=df['payment'],hue=df['color'],palette=['lightgreen','violet'])
# Out:
# <Axes: xlabel='payment', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df
